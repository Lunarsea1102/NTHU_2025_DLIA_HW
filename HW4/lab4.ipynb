# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import nbformat

from google.colab import drive

drive.mount ('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/mydrive')

# Correct the folder path
folder_path = '/content/mydrive/MyDrive/HW04/'  # Updated path

# Verify the path exists
if os.path.exists(folder_path):
    for f in os.listdir(folder_path):
        print(f)
else:
    print(f"Error: The path '{folder_path}' does not exist.")
# Out:
# Drive already mounted at /content/mydrive; to attempt to forcibly remount, call drive.mount("/content/mydrive", force_remount=True).
# nvda.us.txt
# HW4_CNN_LSTM.ipynb
# lab4.ipynb

# %%
import pandas as pd

df = pd.read_csv('/content/mydrive/MyDrive/HW04/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
# !pip install scikit-learn # Install scikit-learn if not already installed
from sklearn.preprocessing import MinMaxScaler # Import MinMaxScaler

import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# Select features
#features = df[['Open', 'High', 'Low', 'Close']]
features = df[['Open', 'High', 'Low', 'Close', 'Volume']] #加Volume
labels = df['High'].shift(-1)  # Next day's high price as label

X, y = create_sequences(features, labels, window_size=30, step=10)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')

#正規化（MinMaxScaler支援多欄）
scaler=MinMaxScaler()
features=scaler.fit_transform(features)
#labels=scaler.fit_transform(labels.values.reshape(-1,1))
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Shape of data X: (471, 30, 5)
# Shape of data y: (471,)
# Shape of data x_train: (339, 30, 5)
# Shape of data y_train: (339,)
# Shape of data x_val: (85, 30, 5)
# Shape of data y_val: (85,)
# Shape of data x_test: (47, 30, 5)
# Shape of data y_test: (47,)
# Number of samples in training and validation are 339 and 85.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Thu May  1 14:53:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

#model = LSTMModel(input_dim=4, hidden_dim=500, num_layers=2, output_dim=1).cuda()
model = LSTMModel(input_dim=5, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)


# Testing LSTM
# Use the trained 'model' instead of 'model_lstm'
model.eval()
with torch.no_grad():
    # Use 'x_test' instead of 'X_test_lstm'
    predictions = model(x_test.cuda()) # Move x_test to cuda as well
    mse = criterion(predictions.squeeze(-1), y_test.cuda()) # Move y_test to cuda and squeeze predictions
    print(f'[LSTM] Test MSE: {mse.item():.6f}')
# Out:
# LSTMModel(
#   (lstm): LSTM(5, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1206.5741, Val loss: 612.5535, Best Val loss: 612.5535
# Epoch 2/100, Train loss: 989.5363, Val loss: 575.6521, Best Val loss: 575.6521
# Epoch 3/100, Train loss: 981.2452, Val loss: 578.1814, Best Val loss: 575.6521
# Epoch 4/100, Train loss: 961.9410, Val loss: 587.5599, Best Val loss: 575.6521
# Epoch 5/100, Train loss: 943.5828, Val loss: 588.4781, Best Val loss: 575.6521
# Epoch 6/100, Train loss: 948.7895, Val loss: 583.5499, Best Val loss: 575.6521
# Epoch 7/100, Train loss: 991.8106, Val loss: 580.4827, Best Val loss: 575.6521
# Epoch 8/100, Train loss: 937.8326, Val loss: 582.1472, Best Val loss: 575.6521
# Epoch 9/100, Train loss: 1063.1469, Val loss: 580.2104, Best Val loss: 575.6521
# Epoch 10/100, Train loss: 951.0948, Val loss: 583.9513, Best Val loss: 575.6521
# Epoch 11/100, Train loss: 1008.8813, Val loss: 582.3316, Best Val loss: 575.6521
# Epoch 12/100, Train loss: 940.5673, Val loss: 582.6484, Best Val loss: 575.6521
# Epoch 13/100, Train loss: 1024.3939, Val loss: 583.5441, Best Val loss: 575.6521
# Epoch 14/100, Train loss: 954.0910, Val loss: 585.7116, Best Val loss: 575.6521
# Epoch 15/100, Train loss: 938.2513, Val loss: 582.7755, Best Val loss: 575.6521
# Epoch 16/100, Train loss: 986.0219, Val loss: 582.0499, Best Val loss: 575.6521
# Epoch 17/100, Train loss: 1011.2183, Val loss: 579.8970, Best Val loss: 575.6521
# Epoch 18/100, Train loss: 987.1245, Val loss: 582.8222, Best Val loss: 575.6521
# Epoch 19/100, Train loss: 940.6968, Val loss: 583.0389, Best Val loss: 575.6521
# Epoch 20/100, Train loss: 975.5502, Val loss: 583.2539, Best Val loss: 575.6521
# Epoch 21/100, Train loss: 976.9436, Val loss: 582.6581, Best Val loss: 575.6521
# Epoch 22/100, Train loss: 939.9162, Val loss: 585.7679, Best Val loss: 575.6521
# Epoch 23/100, Train loss: 979.2271, Val loss: 582.0861, Best Val loss: 575.6521
# Epoch 24/100, Train loss: 955.6968, Val loss: 580.0837, Best Val loss: 575.6521
# Epoch 25/100, Train loss: 988.5685, Val loss: 583.4077, Best Val loss: 575.6521
# Epoch 26/100, Train loss: 943.3883, Val loss: 585.6057, Best Val loss: 575.6521
# Epoch 27/100, Train loss: 956.0118, Val loss: 580.0570, Best Val loss: 575.6521
# Epoch 28/100, Train loss: 941.2102, Val loss: 579.8505, Best Val loss: 575.6521
# Epoch 29/100, Train loss: 979.4240, Val loss: 579.0630, Best Val loss: 575.6521
# Epoch 30/100, Train loss: 995.7547, Val loss: 581.9528, Best Val loss: 575.6521
# Epoch 31/100, Train loss: 981.5299, Val loss: 583.1441, Best Val loss: 575.6521
# Epoch 32/100, Train loss: 994.1603, Val loss: 583.4970, Best Val loss: 575.6521
# Epoch 33/100, Train loss: 949.8222, Val loss: 582.1749, Best Val loss: 575.6521
# Epoch 34/100, Train loss: 967.9075, Val loss: 583.0484, Best Val loss: 575.6521
# Epoch 35/100, Train loss: 940.8931, Val loss: 581.8788, Best Val loss: 575.6521
# Epoch 36/100, Train loss: 940.5251, Val loss: 583.0757, Best Val loss: 575.6521
# Epoch 37/100, Train loss: 946.7795, Val loss: 581.0848, Best Val loss: 575.6521
# Epoch 38/100, Train loss: 986.3158, Val loss: 579.4946, Best Val loss: 575.6521
# Epoch 39/100, Train loss: 946.6756, Val loss: 582.9527, Best Val loss: 575.6521
# Epoch 40/100, Train loss: 937.6437, Val loss: 582.9332, Best Val loss: 575.6521
# Epoch 41/100, Train loss: 986.9109, Val loss: 582.8514, Best Val loss: 575.6521
# Epoch 42/100, Train loss: 942.5865, Val loss: 583.5162, Best Val loss: 575.6521
# Epoch 43/100, Train loss: 946.6482, Val loss: 581.9267, Best Val loss: 575.6521
# Epoch 44/100, Train loss: 965.2584, Val loss: 580.6923, Best Val loss: 575.6521
# Epoch 45/100, Train loss: 936.9154, Val loss: 581.7642, Best Val loss: 575.6521
# Epoch 46/100, Train loss: 1041.5976, Val loss: 580.5430, Best Val loss: 575.6521
# Epoch 47/100, Train loss: 967.3032, Val loss: 582.9137, Best Val loss: 575.6521
# Epoch 48/100, Train loss: 943.7801, Val loss: 583.8911, Best Val loss: 575.6521
# Epoch 49/100, Train loss: 956.2982, Val loss: 584.9092, Best Val loss: 575.6521
# Epoch 50/100, Train loss: 978.5129, Val loss: 585.1921, Best Val loss: 575.6521
# Epoch 51/100, Train loss: 934.5679, Val loss: 582.7986, Best Val loss: 575.6521
# Epoch 52/100, Train loss: 995.4803, Val loss: 582.1572, Best Val loss: 575.6521
# Epoch 53/100, Train loss: 1000.0728, Val loss: 581.4169, Best Val loss: 575.6521
# Epoch 54/100, Train loss: 936.2806, Val loss: 581.9481, Best Val loss: 575.6521
# Epoch 55/100, Train loss: 1017.4888, Val loss: 580.6548, Best Val loss: 575.6521
# Epoch 56/100, Train loss: 979.1883, Val loss: 583.4118, Best Val loss: 575.6521
# Epoch 57/100, Train loss: 940.3082, Val loss: 582.7641, Best Val loss: 575.6521
# Epoch 58/100, Train loss: 941.5252, Val loss: 582.7793, Best Val loss: 575.6521
# Epoch 59/100, Train loss: 1018.9113, Val loss: 582.8310, Best Val loss: 575.6521
# Epoch 60/100, Train loss: 939.1859, Val loss: 583.4330, Best Val loss: 575.6521
# Epoch 61/100, Train loss: 1063.0300, Val loss: 582.2081, Best Val loss: 575.6521
# Epoch 62/100, Train loss: 946.6020, Val loss: 583.0746, Best Val loss: 575.6521
# Epoch 63/100, Train loss: 993.7182, Val loss: 583.1315, Best Val loss: 575.6521
# Epoch 64/100, Train loss: 968.7994, Val loss: 583.3275, Best Val loss: 575.6521
# Epoch 65/100, Train loss: 980.6981, Val loss: 583.0685, Best Val loss: 575.6521
# Epoch 66/100, Train loss: 981.9578, Val loss: 583.6512, Best Val loss: 575.6521
# Epoch 67/100, Train loss: 977.9902, Val loss: 583.8312, Best Val loss: 575.6521
# Epoch 68/100, Train loss: 1003.1623, Val loss: 583.1583, Best Val loss: 575.6521
# Epoch 69/100, Train loss: 948.1362, Val loss: 583.0583, Best Val loss: 575.6521
# Epoch 70/100, Train loss: 962.7844, Val loss: 583.4595, Best Val loss: 575.6521
# Epoch 71/100, Train loss: 1027.7048, Val loss: 583.0080, Best Val loss: 575.6521
# Epoch 72/100, Train loss: 937.6397, Val loss: 583.3966, Best Val loss: 575.6521
# Epoch 73/100, Train loss: 937.6298, Val loss: 583.7054, Best Val loss: 575.6521
# Epoch 74/100, Train loss: 965.3396, Val loss: 582.6719, Best Val loss: 575.6521
# Epoch 75/100, Train loss: 1003.6217, Val loss: 582.9699, Best Val loss: 575.6521
# Epoch 76/100, Train loss: 936.5979, Val loss: 583.1975, Best Val loss: 575.6521
# Epoch 77/100, Train loss: 938.0906, Val loss: 582.6302, Best Val loss: 575.6521
# Epoch 78/100, Train loss: 976.7323, Val loss: 582.1960, Best Val loss: 575.6521
# Epoch 79/100, Train loss: 945.6543, Val loss: 582.3437, Best Val loss: 575.6521
# Epoch 80/100, Train loss: 992.2706, Val loss: 582.2991, Best Val loss: 575.6521
# Epoch 81/100, Train loss: 937.3759, Val loss: 582.2599, Best Val loss: 575.6521
# Epoch 82/100, Train loss: 979.8312, Val loss: 582.1529, Best Val loss: 575.6521
# Epoch 83/100, Train loss: 948.6554, Val loss: 582.2872, Best Val loss: 575.6521
# Epoch 84/100, Train loss: 966.5687, Val loss: 582.2457, Best Val loss: 575.6521
# Epoch 85/100, Train loss: 977.3969, Val loss: 582.3072, Best Val loss: 575.6521
# Epoch 86/100, Train loss: 975.3674, Val loss: 582.2337, Best Val loss: 575.6521
# Epoch 87/100, Train loss: 937.1387, Val loss: 582.4730, Best Val loss: 575.6521
# Epoch 88/100, Train loss: 1007.7077, Val loss: 582.3398, Best Val loss: 575.6521
# Epoch 89/100, Train loss: 936.6900, Val loss: 582.5015, Best Val loss: 575.6521
# Epoch 90/100, Train loss: 951.2231, Val loss: 582.4777, Best Val loss: 575.6521
# Epoch 91/100, Train loss: 996.5572, Val loss: 582.4611, Best Val loss: 575.6521
# Epoch 92/100, Train loss: 938.3313, Val loss: 582.4650, Best Val loss: 575.6521
# Epoch 93/100, Train loss: 956.8838, Val loss: 582.4520, Best Val loss: 575.6521
# Epoch 94/100, Train loss: 1013.7654, Val loss: 582.4455, Best Val loss: 575.6521
# Epoch 95/100, Train loss: 993.6023, Val loss: 582.4565, Best Val loss: 575.6521
# Epoch 96/100, Train loss: 937.3066, Val loss: 582.4757, Best Val loss: 575.6521
# Epoch 97/100, Train loss: 982.6310, Val loss: 582.4720, Best Val loss: 575.6521
# Epoch 98/100, Train loss: 971.4279, Val loss: 582.4719, Best Val loss: 575.6521
# Epoch 99/100, Train loss: 934.6303, Val loss: 582.4735, Best Val loss: 575.6521
# Epoch 100/100, Train loss: 936.6888, Val loss: 582.4725, Best Val loss: 575.6521
# [LSTM] Test MSE: 1372.205933

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()

# %%
from google.colab import drive
drive.flush_and_unmount()  # 先卸載
drive.mount('/content/mydrive')  # 然後再掛載一次
# Out:
# Mounted at /content/mydrive
